# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp
from scipy.optimize import minimize
import matplotlib.animation as animation

# %% [markdown]
# Innitial conditions:

# %%
G = 6.67430e-11
M_sun = 1.989e30
M_earth = 5.972e37
M_mars = 6.39e23
AU = 1.496e11
R_earth_mars = 1.52

earth position
distence mars sum
Speed orbit

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp
from scipy.optimize import minimize
import matplotlib.animation as animation

G = 6.67430e-11
M_sun = 1.989e30
M_earth = 5.972e37
M_mars = 6.39e23
AU = 1.496e11 #[m]
R_earth_mars = 1.52
R_earth_sun =  1 

p_earth = np.array([1.0, 0.0])
p_mars = np.array([1.52, 0.0])
p_ship = p_earth + np.array([0.0001, 0.0])  # Near Earth

# (AU/year)
v_earth = np.array([0.0, 2*np.pi])
v_mars = np.array([0.0, 2*np.pi/np.sqrt(1.52)])
v_ship = v_earth + np.array([0.0, #escape velocity#])

#escape velocity with formula
